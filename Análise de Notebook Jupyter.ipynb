# %%
# Let's load the Jupyter notebook to examine its contents.
import nbformat

# Load the notebook file
file_path = 'Calibração e Validação.ipynb'

with open(file_path, 'r', encoding='utf-8') as f:
    notebook = nbformat.read(f, as_version=4)

# Extract the cells of the notebook
cells = notebook.cells

# %%
from IPython.display import HTML

for cell in cells:
    print('')
    print('```python')
    print(cell['source'])
    print('```')
    
    if 'outputs' in cell:

        # for out in cell['outputs']:

            # if out['output_type'] != 'stream':
    
                # if '' out['data']
            
        # print({out['output_type']: out.keys() for out in cell['outputs']})
        for out in cell['outputs']:
            if out['output_type'] != 'stream':
                # print(f"{out['output_type']}: {list(out['data'].keys())}")
                # print(out['data']['text/plain'])

                if 'text/plain' in out['data']:
                    print('```output (text/plain)')
                    print(out['data']['text/plain'])
                    print('```')

                # if 'text/html' in out['data']:
                    # if len(out['data']['text/html']) < 1e5:
                    # display(HTML(out['data']['text/html']))

                        # print(out['data']['text/html'])

                # if 'application/vnd.plotly.v1+json' in out['data']:
                #     print(out['data']['text/html'])
                #     open('test.html', 'w').write(out['data']['text/html'])
                #     break
# Out:
# ```python
# # SMAP para Bacia de Camargos - Calibração e Validação
# ```
#
# ```python
# #### To-Do
# ```
#
# ```python
# - Ouvir aula (conferir se existe um método padrão para calibração)
# - Identify and explain the most important parameters for accuracy
# ```
#
# ```python
# #### Load data
# ```
#
# ```python
# import pandas as pd
# # df = pd.read_csv('data/smap_input.csv')
# df = pd.read_csv('data/bacia-camargos.csv')
#
# # Data cleaning
# df['Ep'] = df['Ep'].str.replace(',', '.').astype('float')
# df['Pr'] = df['Pr'].str.replace(',', '.').astype('float')
#
# df.set_index(pd.to_datetime(df['data']), inplace=True)
# df.drop('data', axis=1, inplace=True)
#
# df.head()
# ```
# ```output (text/plain)
#             Qobs    Ep    Pr
# data
# 1995-01-01   204  4.94   4.3
# 1995-01-02   181  4.94   9.1
# 1995-01-03   176  4.94  22.8
# 1995-01-04   194  4.94   9.2
# 1995-01-05   198  4.94   1.7
# ```
#
# ```python
# ---
# # Modelo Base
# ```
#
# ```python
# ...

# %%
outputs = cells[i]['outputs']
for out in outputs:

    if 'text/html' in out['data']:
        display(HTML(out['data']['text/html']))
    else:
        print(out)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Q - BASE</th>
#       <th>Q - ONS</th>
#       <th>Q - OPT GRID</th>
#       <th>Q - OPT RAND</th>
#       <th>Q - OPT BAY</th>
#       <th>Q - OPT GEN</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>cef</th>
#       <td>0.316289</td>
#       <td>0.793380</td>
#       <td>0.627835</td>
#       <td>0.482649</td>
#       <td>0.596397</td>
#       <td>0.851605</td>
#     </tr>
#     <tr>
#       <th>cer</th>
#       <td>0.651888</td>
#       <td>0.871702</td>
#       <td>0.669828</td>
#       <td>0.666273</td>
#       <td>0.617783</td>
#       <td>0.811392</td>
#     </tr>
#     <tr>
# ...
